# %%
import pandas as pd

# %%
data = pd.read_csv('NewComb2.csv')

# %%
data.head()
# Out:
#   Highest Layer Transport Layer  Source IP       Dest IP  Source Port  \
# 0           ARP             UDP          1   192.168.1.1            0
# 1           ARP             UDP          0  192.168.1.10            0
# 2           ARP             UDP          1   192.168.1.1            0
# 3           ARP             UDP          0  192.168.1.12            0
# 4           ARP             UDP          1   192.168.1.1            0
#
#    Dest Port  Packet Length  Packets/Time  target
# 0          0             60         92.75       1
# 1          0             42         92.86       0
# 2          0             60        362.77       1
# 3          0             42        362.79       0
# 4          0             60        364.31       1

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %%
data.head()
# Out:
#   Highest Layer Transport Layer  Source IP      Dest IP  Source Port  \
# 0          DATA             TCP          0  192.168.1.1        49158
# 1          ICMP            None          0  192.168.1.2            0
# 2          DATA             TCP          0  192.168.1.1        49158
# 3          QUIC             UDP          1  192.168.1.1        56187
# 4          QUIC             UDP          1  192.168.1.1        61636
#
#    Dest Port  Packet Length  Packets/Time  target
# 0       5201           1514        249.56       0
# 1          0             74        292.10       0
# 2       5201           1514        289.44       0
# 3         80             60        467.79       1
# 4         80             60        479.57       1
